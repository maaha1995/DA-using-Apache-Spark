# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext
sc =SparkContext.getOrCreate()
sqlContext = SQLContext(sc)

from operator import add
import sys
import os
import csv
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))
stop_words.add("advertisement")
stop_words.add("said")
stop_words.add("")
stop_words.add(" ")
stop_words.add("  ")
stop_words.add("ms")
stop_words.add("house")
stop_words.add("brown")
stop_words.add("people")
#stop_words.add("olympic")
stop_words.add("year")
stop_words.add("years")
stop_words.add("time")
stop_words.add("state")
stop_words.add("states")
stop_words.add("women")
stop_words.add("gallon")
stop_words.add("juan")
stop_words.add("trump")
stop_words.add("york")
stop_words.add("rico")
stop_words.add("puerto")
stop_words.add("san")
stop_words.add("island")

filepath = "/Users/mahalakshmimaddu/Desktop/DICLab3/Part2/CleanedFiles/Business/"

for file in os.listdir(filepath):
    textRDD = sc.textFile(filepath)
    words = textRDD.flatMap(lambda x: x.split(' ')).map(lambda x: (x, 1))
    print(str(words))
    wordcount = words.reduceByKey(add).collect()
output = sorted(wordcount, key = lambda x:x[1], reverse=True)

top_words = []
is_noun = lambda pos: pos[:2] == 'NN'

i = 0;
x = 0;
while x < len(output) and i < 20:
    word = [output[x][0].encode('ascii','ignore')]
    if(bool(word[0].strip())):
        l1 =  nltk.tag.pos_tag(word)
        if ((is_noun(l1[0][1])) and (not (word[0].lower() in (stop_words))) and len(word[0]) > 2):
            top_words.append(output[x][0])
            i = i+1;
            x = x+1;
        else:
            x = x+1;
    else:
        x = x+1;
print(str(top_words))

new_words = []
for i in range(len(top_words)):
    new_words.append(top_words[i].encode('utf-8'))
print(str(new_words))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mahalakshmimaddu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/mahalakshmimaddu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mahalakshmimaddu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# PythonRDD[2] at RDD at PythonRDD.scala:48
# PythonRDD[10] at RDD at PythonRDD.scala:48
# PythonRDD[18] at RDD at PythonRDD.scala:48
# PythonRDD[26] at RDD at PythonRDD.scala:48
# PythonRDD[34] at RDD at PythonRDD.scala:48
# PythonRDD[42] at RDD at PythonRDD.scala:48
# PythonRDD[50] at RDD at PythonRDD.scala:48
# PythonRDD[58] at RDD at PythonRDD.scala:48
# PythonRDD[66] at RDD at PythonRDD.scala:48
# PythonRDD[74] at RDD at PythonRDD.scala:48
# PythonRDD[82] at RDD at PythonRDD.scala:48
# PythonRDD[90] at RDD at PythonRDD.scala:48
# PythonRDD[98] at RDD at PythonRDD.scala:48
# PythonRDD[106] at RDD at PythonRDD.scala:48
# PythonRDD[114] at RDD at PythonRDD.scala:48
# PythonRDD[122] at RDD at PythonRDD.scala:48
# PythonRDD[130] at RDD at PythonRDD.scala:48
# PythonRDD[138] at RDD at PythonRDD.scala:48
# PythonRDD[146] at RDD at PythonRDD.scala:48
# PythonRDD[154] at RDD at PythonRDD.scala:48
# [u'percent', u'business', u'company', u'points', u'companies', u'businesses', u'stocks', u'sales', u'workers', u'index', u'quarter', u'power', u'oil', u'trade', u'mobile', u'sprint', u'share', u'industry', u'months', u'deal']
# ['percent', 'business', 'company', 'points', 'companies', 'businesses', 'stocks', 'sales', 'workers', 'index', 'quarter', 'power', 'oil', 'trade', 'mobile', 'sprint', 'share', 'industry', 'months', 'deal']

# %%
'percent', 'business', 'company', 'points', 'companies', 'businesses', 'stocks', 'sales', 'workers', 'index', 'quarter', 'power', 'oil', 'trade', 'mobile', 'sprint', 'share', 'industry', 'months', 'deal',
